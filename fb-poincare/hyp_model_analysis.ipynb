# %%
import pickle

import model_eval

# %%
# model_fname = './log/exp2.1_ext_taxo_epc10000_lr0.1_dim15_neg10/book_model.pth'
model_fname = './log/exp2.2_int_taxo_epc10000_lr0.1_dim15_neg10/book_model.pth'
bookmap_fname = './book_title_id.pkl'

# %%
info_dict = model_eval.get_model_info(model_fname)

# %%
with open(bookmap_fname, 'rb') as rfile:
    bookmap_dict = pickle.load(rfile)

# %%
bookmap_dict
# Out:
# {'The Hunger Games (The Hunger Games, #1)': 1,
#  "Harry Potter and the Sorcerer's Stone (Harry Potter, #1)": 2,
#  'Twilight (Twilight, #1)': 3,
#  'To Kill a Mockingbird': 4,
#  'The Great Gatsby': 5,
#  'The Fault in Our Stars': 6,
#  'The Hobbit': 7,
#  'The Catcher in the Rye': 8,
#  'Angels & Demons  (Robert Langdon, #1)': 9,
#  'Pride and Prejudice': 10,
#  'The Kite Runner': 11,
#  'Divergent (Divergent, #1)': 12,
#  '1984': 13,
#  'Animal Farm': 14,
#  'The Diary of a Young Girl': 15,
#  'The Girl with the Dragon Tattoo (Millennium, #1)': 16,
#  'Catching Fire (The Hunger Games, #2)': 17,
#  'Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)': 18,
#  'The Fellowship of the Ring (The Lord of the Rings, #1)': 19,
#  'Mockingjay (The Hunger Games, #3)': 20,
#  'Harry Potter and the Order of the Phoenix (Harry Potter, #5)': 21,
#  'The Lovely Bones': 22,
#  'Harry Potter and the Chamber of Secrets (Harry Potter, #2)': 23,
# ...

# %%
rev_bookmap = {}
for key, val in bookmap_dict.items():
    rev_bookmap[val] = key

# %%
rev_bookmap
# Out:
# {1: 'The Hunger Games (The Hunger Games, #1)',
#  2: "Harry Potter and the Sorcerer's Stone (Harry Potter, #1)",
#  3: 'Twilight (Twilight, #1)',
#  4: 'To Kill a Mockingbird',
#  5: 'The Great Gatsby',
#  6: 'The Fault in Our Stars',
#  7: 'The Hobbit',
#  8: 'The Catcher in the Rye',
#  9: 'Angels & Demons  (Robert Langdon, #1)',
#  10: 'Pride and Prejudice',
#  11: 'The Kite Runner',
#  12: 'Divergent (Divergent, #1)',
#  13: '1984',
#  14: 'Animal Farm',
#  15: 'The Diary of a Young Girl',
#  16: 'The Girl with the Dragon Tattoo (Millennium, #1)',
#  17: 'Catching Fire (The Hunger Games, #2)',
#  18: 'Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)',
#  19: 'The Fellowship of the Ring (The Lord of the Rings, #1)',
#  20: 'Mockingjay (The Hunger Games, #3)',
#  21: 'Harry Potter and the Order of the Phoenix (Harry Potter, #5)',
#  22: 'The Lovely Bones',
#  23: 'Harry Potter and the Chamber of Secrets (Harry Potter, #2)',
# ...

# %%
out_fname = './bookid_totitle_py2.pkl'
with open(out_fname, 'wb') as ofile:
    pickle.dump(rev_bookmap, ofile, protocol=2)

# %%
target = '1'

# %%
rev_bookmap[int(target)]
# Out:
# 'The Hunger Games (The Hunger Games, #1)'

# %%
# print(info_dict['idmap'].keys())

# %%
# otlist = ['vampires', 'mental-health', 'history-of-science', 'animal-fiction', 'environment', 'culinary', 'geology', 'horror', 'storytime', '14th-century', 'high-fantasy', 'fae', 'school', 'magic', 'international-relations', 'romantic-suspense', 'adult-fiction', 'non-fiction', 'middle-grade', 'gothic-romance', 'german-literature', 'read-for-school', '17th-century', 'plays', 'cooking', 'asia', 'international', 'iran', 'russian-literature', 'childrens-classics', 'lgbt', 'china', 'political-science', 'tragedy', 'american-civil-war', 'christian-non-fiction', 'high-school', 'economics', 'comic-book', 'action', 'family', 'egypt', 'presidents', 'africa', 'fairy-tales', 'social-work', 'womens-fiction', 'english-literature', 'france', 'angels', 'horses', 'israel', 'biblical', 'halloween', 'us-presidents', 'microhistory', '21st-century', 'paranormal-romance', 'animals', 'science', 'edwardian', 'movies', 'history', 'foodie', 'india', 'romanticism', 'dragons', 'gothic-horror', 'counting', 'biography', 'world-war-ii', 'autobiography', '1st-grade', 'travel', 'poetry', 'comedy', 'memoir', 'latin-american', 'contemporary-romance', 'funny', 'philosophy', 'southern', 'entrepreneurship', 'sustainability', 'abuse', 'adventure', 'cults', 'historical-fantasy', 'manga', 'mystery-thriller', 'zen', 'westerns', 'brain', 'japan', 'military-science-fiction', 'birds', 'islam', 'chinese-literature', 'writing', 'space-opera', 'british-literature', 'historical-mystery', 'holiday', 'fairy-tale-retellings', 'picture-books', 'asian-literature', 'finance', 'food', 'coming-of-age', 'judaism', 'occult', 'true-crime', 'popular-science', 'fitness', 'aspergers', 'european-history', 'pirates', 'books-about-books', 'natural-history', 'southern-gothic', 'ghosts', 'agriculture', 'dark-fantasy', 'canada', 'retellings', 'french-revolution', 'space', 'god', 'activism', 'research', 'health', 'medicine', 'eastern-philosophy', 'theory', 'road-trip', 'ancient', 'arthurian', 'cookbooks', 'language', 'dinosaurs', '19th-century', 'computers', 'american', 'steampunk', 'sword-and-sorcery', 'comix', '16th-century', 'cinderella', 'americana', 'fantasy', 'spanish-civil-war', 'self-help', '20th-century', 'erotic-romance', 'management', 'divorce', 'art-history', 'fiction', 'epic-poetry', 'indian-literature', 'nigeria', 'dogs', 'danish', 'spanish-literature', 'new-adult', 'american-history', 'essays', 'social-justice', 'holland', 'epic-fantasy', 'sweden', 'historical', 'outdoors', 'russia', 'illness', 'nutrition', 'modern', 'irish-literature', 'suspense', 'historical-fiction', 'realistic-fiction', 'botswana', 'japanese-literature', 'catholic', 'latin-american-literature', 'werewolves', 'scotland', 'anthologies', 'judaica', 'banned-books', 'young-adult-fantasy', 'chapter-books', 'theatre', 'alternate-universe', 'germany', 'class', 'mental-illness', 'funnies', 'czech-literature', 'disease', 'physics', 'detective', 'international-development', 'walking', 'contemporary', 'short-stories', 'young-readers', 'soldiers', 'geography', 'noir', 'italian-literature', 'crime', 'alternate-history', 'spirituality', 'money', 'world-history', 'mysticism', 'greek-mythology', 'evolution', 'dc-comics', 'denmark', 'witches', 'canadian-literature', 'art', 'cozy-mystery', 'reference', 'young-adult-romance', 'college', 'cyberpunk', 'greece', 'christian', 'short-story-collection', 'brazil', 'victorian', 'demons', 'swedish-literature', 'supernatural', 'nature', 'ancient-history', 'poverty', 'graphic-novels', 'pakistan', 'hackers', 'paranormal', 'biblical-fiction', 'church', 'swashbuckling', 'african-literature', 'ireland', 'magical-realism', 'gay', 'regency', 'folklore', 'spain', 'prehistoric', 'african-american', 'african-american-literature', 'holocaust', 'hard-science-fiction', 'mythology', 'novella', 'psychological-thriller', 'love-story', 'portugal', 'christian-fiction', 'gothic', 'boarding-school', 'technology', 'superheroes', 'fantasy-romance', 'italy', 'american-fiction', 'romance', 'buddhism', 'wizards', 'spy-thriller', 'terrorism', 'modern-classics', 'literature', 'american-revolution', 'novels', 'personal-development', 'climbing', 'scandinavian-literature', 'literary-fiction', 'cartoon', 'poland', 'urban-fantasy', 'post-apocalyptic', 'theology', 'academic', 'academia', 'speculative-fiction', 'chemistry', 'gods', 'legal-thriller', 'mountaineering', 'lds', 'science-fiction', 'collections', 'time-travel-romance', 'sequential-art', 'mystery', 'australia', 'government', 'survival', 'fairies', 'cultural', 'social-issues', 'journalism', 'shapeshifters', 'civil-war', 'zombies', 'travelogue', 'ecology', '12th-century', 'military-fiction', 'lebanon', 'classic-literature', 'french-literature', 'sociology', 'humor', 'american-classics', 'historical-romance', 'religion', '18th-century', 'whodunit', 'epic', 'young-adult', 'christmas', 'espionage', 'apocalyptic', 'biology', 'fables', 'medieval', 'business', 'comic-strips', 'erotica', 'faith', 'dystopia', 'drama', 'folk-tales', 'classics', 'black-literature', 'childrens', 'wilderness', 'communication', 'aliens', 'sports', 'european-literature', 'food-and-drink', 'christianity', 'cats', 'thriller', 'war', 'portuguese-literature', 'jewish', 'batman', 'world-war-i', 'comics', 'chick-lit', 'teen', 'juvenile', 'rabbits', 'engineering', 'christian-living', 'planets', 'politics', 'algeria', 'humanities', 'food-writing', 'mathematics', 'students', 'robots', 'military-history', 'murder-mystery', 'mormonism', 'astronomy', 'time-travel', 'classical-studies', '143', '213', '295', '112', 'science-fiction-fantasy', 'adult', 'unfinished', 'anthropology', 'science-nature', 'education', 'dark', 'roman', 'psychology', 'inspirational', 'biography-memoir', 'relationships', 'love', 'social-science', 'society', 'social', 'death', 'teaching', 'disability', 'true-story', 'romantic', 'architecture', 'feminism', 'queer', 'gender', 'sexuality', 'leadership', 'united-states', 'police', 'new-york', 'race', 'medical', 'futuristic', 'productivity', 'how-to', 'surreal', 'criticism', 'fashion', 'adolescence', 'law', 'graphic-novels-comics', 'comics-manga', 'graphic-novels-manga', 'music', 'artificial-intelligence', 'lesbian', 'games', 'adoption', 'martial-arts', 'polygamy', 'witchcraft', 'textbooks', 'urban', 'diary']
otlist = list(info_dict['idmap'].keys())

# %%
target in otlist
# Out:
# True

# %%
len(otlist)
# Out:
# 1140

# %%
dists1, sorted_ids1 = model_eval.compute_nn(target, otlist, info_dict, func='dist')
dists2, sorted_ids2 = model_eval.compute_nn(target, otlist, info_dict, func='isa', alpha=1000)
dists3, sorted_ids3 = model_eval.compute_nn(target, otlist, info_dict, func='rank', beta=10)

# %%
for i in sorted_ids1:
#     print(otlist[i])
    try:
        key = int(otlist[i])
        if key in rev_bookmap:
            print(rev_bookmap[key], i)
    except:
        print(rev_bookmap[i])
# Out:
# The Hunger Games (The Hunger Games, #1) 536
# Bloodlines (Bloodlines, #1) 15
# Cress (The Lunar Chronicles, #3) 306
# Alexander and the Terrible, Horrible, No Good, Very Bad Day
# Beautiful Ruins
# Anansi Boys
# The Husband's Secret 13
# The Passage (The Passage, #1)
# Hopeless (Hopeless, #1) 24
# Born to Run: A Hidden Tribe, Superathletes, and the Greatest Race the World Has Never Seen
# Sphere
# Shantaram
# On Writing: A Memoir of the Craft
# Dreams from My Father: A Story of Race and Inheritance
# Congo
# Breakfast at Tiffany's
# Invisible Man
# The Silver Linings Playbook
# The Vampire Lestat (The Vampire Chronicles, #2)
# The Scarlet Letter 22
# Twenty Thousand Leagues Under the Sea
# Thinner
# Eleven Minutes
# Love the One You're With
# Mort (Death, #1; Discworld, #4)
# Wool Omnibus (Silo, #1)
# The Notebook (The Notebook, #1) 550
# Entwined with You (Crossfire, #3)
# 1776
# The Constant Princess (The Plantagenet and Tudor Novels, #6)
# The Cider House Rules
# Americanah
# ...

# %%
for i in sorted_ids2:
    try:
        key = int(otlist[i])
        if key in rev_bookmap:
            print(rev_bookmap[key])
    except:
        print(i)
# Out:
# Persepolis: The Story of a Childhood (Persepolis, #1)
# And the Mountains Echoed
# World War Z: An Oral History of the Zombie War
# A Monster Calls
# Never Let Me Go
# The Kite Runner
# Stiff: The Curious Lives of Human Cadavers
# The 5th Wave (The 5th Wave, #1)
# I Know Why the Caged Bird Sings
# Odd Thomas (Odd Thomas, #1)
# The Adventures of Sherlock Holmes
# Me Before You (Me Before You, #1)
# The Old Man and the Sea
# Throne of Glass (Throne of Glass, #1)
# A People's History of the United States
# The Host (The Host, #1)
# A Light in the Attic
# The Horse and His Boy (Chronicles of Narnia, #5)
# Guns, Germs, and Steel: The Fates of Human Societies
# The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change
# A Discovery of Witches (All Souls Trilogy, #1)
# The Unbearable Lightness of Being
# Flowers for Algernon
# The Fellowship of the Ring (The Lord of the Rings, #1)
# A Clockwork Orange
# The Rainmaker
# ...

# %%
for i in sorted_ids3:
    try:
        key = int(otlist[i])
        if key in rev_bookmap:
            print(rev_bookmap[key])
    except:
        print(i)
# Out:
# Big Little Lies
# Cress (The Lunar Chronicles, #3)
# Bloodlines (Bloodlines, #1)
# Extremely Loud and Incredibly Close
# Walking Disaster (Beautiful, #2)
# The Notebook (The Notebook, #1)
# The Hunt for Red October (Jack Ryan Universe, #4)
# Sabriel (Abhorsen,  #1)
# The Ultimate Hitchhiker's Guide to the Galaxy
# Safe Haven
# The Phantom Tollbooth
# Harold and the Purple Crayon
# Needful Things
# Timeline
# Brave New World / Brave New World Revisited
# The Client
# Heidi
# P.S. I Love You
# The Count of Monte Cristo
# Charlotte's Web
# The Golden Compass (His Dark Materials, #1)
# The Sisterhood of the Traveling Pants (Sisterhood, #1)
# Harry Potter and the Order of the Phoenix (Harry Potter, #5)
# Much Ado About Nothing
# Hopeless (Hopeless, #1)
# Where the Sidewalk Ends
# Song of Susannah (The Dark Tower, #6)
# The Fiery Cross (Outlander, #5)
# Dead to the World (Sookie Stackhouse, #4)
# Northanger Abbey
# The Velveteen Rabbit
# The Cat in the Hat
# Black Beauty
# ...

# %%
"""
Booknames and their ids:

booklist = ["The Hunger Games (The Hunger Games, #1)",
                   "Harry Potter and the Sorcerer's Stone (Harry Potter, #1)",
                   "Twilight (Twilight, #1)",
                   "To Kill a Mockingbird",
                   "The Great Gatsby",
                   "The Fault in Our Stars",
                   "The Hobbit",
                   "The Catcher in the Rye",
                   "Angels & Demons  (Robert Langdon, #1)",
                   "Pride and Prejudice"]

"""
a = 10

# %%
booklist = ["The Hunger Games (The Hunger Games, #1)",
                   "Harry Potter and the Sorcerer's Stone (Harry Potter, #1)",
                   "Twilight (Twilight, #1)",
                   "To Kill a Mockingbird",
                   "The Great Gatsby",
                   "The Fault in Our Stars",
                   "The Hobbit",
                   "The Catcher in the Rye",
                   "Angels & Demons  (Robert Langdon, #1)",
                   "Pride and Prejudice"]

# %%
bookmap_dict["Harry Potter and the Sorcerer's Stone (Harry Potter, #1)"]
# Out:
# 2

# %%
bookids = []
for b in booklist:
    tmp_id = bookmap_dict[b]
    print(tmp_id)
    bookids.append(tmp_id)
    print(str(tmp_id) in info_dict['idmap'])
# Out:
# 1
# True
# 2
# True
# 3
# True
# 4
# True
# 5
# True
# 6
# True
# 7
# True
# 8
# True
# 9
# True
# 10
# True

# %%
all_books = []
for k in info_dict['idmap'].keys():  
    try:
        key = int(k)
    except:
        continue
    if key in rev_bookmap:
        bookname = rev_bookmap[key]
        all_books.append(bookname)

# %%
all_books
# Out:
# ['The Da Vinci Code (Robert Langdon, #2)',
#  'Needful Things',
#  'Fire (Graceling Realm, #2)',
#  'Patriot Games (Jack Ryan Universe, #2)',
#  'Shadow Kiss (Vampire Academy, #3)',
#  'Northanger Abbey',
#  "Ender's Game (Ender's Saga, #1)",
#  'The Kitchen House',
#  'The Great Hunt (Wheel of Time, #2)',
#  'The Maze Runner (Maze Runner, #1)',
#  'The Horse and His Boy (Chronicles of Narnia, #5)',
#  'The Help',
#  'The Catcher in the Rye',
#  "The Husband's Secret",
#  'Where the Red Fern Grows',
#  'Bloodlines (Bloodlines, #1)',
#  'Changes (The Dresden Files, #12)',
#  'Dead to the World (Sookie Stackhouse, #4)',
#  'Dark Places',
#  "Charlotte's Web",
#  'Prince Caspian (Chronicles of Narnia, #2)',
#  'The Pillars of the Earth (The Kingsbridge Series, #1)',
#  'The Scarlet Letter',
#  'The Drawing of the Three (The Dark Tower, #2)',
#  'Hopeless (Hopeless, #1)',
#  'Point of Retreat (Slammed, #2)',
#  'Like Water for Chocolate',
#  'Winter (The Lunar Chronicles, #4)',
# ...

# %%
norms_sorted_ids, norms_names, norms = model_eval.sort_by_norm(info_dict)

# %%
count = 0
maxcount = 10
for num, i in enumerate(norms_names):
    count +=1 
    if count > maxcount:
        break
    try:
        k = int(i)
        if k in rev_bookmap.keys():
            print(rev_bookmap[k], norms[norms_sorted_ids[num]])
    except:
        print(i, norms[norms_sorted_ids[num]])
# Out:
# classics 0.38442849997149725
# science 0.6637261435930318
# witches 0.6986874676584568
# teen 0.7185775624376597
# unfinished 0.8070565260401409
# 20th-century 0.8385958006537731
# action 0.859746451466281
# childrens 0.8696402620402995
# chapter-books 0.8757259083982678
# high-fantasy 0.8765149599706505
